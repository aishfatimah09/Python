# %%
import pandas as pd
import matplotlib.pyplot as plt

df_exam = pd.read_csv("student_exam_data.csv")

df_exam_first = df_exam.head(10)
x = df_exam_first['Study Hours']
y = df_exam_first['Previous Exam Score']


plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Study Hours')
plt.ylabel('Previous Exam Score')
plt.title('Exam Scores of Students')
plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
df_exam = pd.read_csv("student_exam_data.csv")
x = df_exam['Study Hours']
y = df_exam['Previous Exam Score']
plt.plot(x, y, marker='o', linestyle='-')
plt.xlabel('Study Hours')
plt.ylabel('Previous Exam Score')
plt.title('Exam Scores of Students')
plt.grid(True)
plt.show()

# %%
import pandas as pd
df_exam = pd.read_csv("student_exam_data.csv")
print(df_exam.head(10))
# Out:
#    Study Hours  Previous Exam Score  Pass/Fail
# 0     4.370861            81.889703          0
# 1     9.556429            72.165782          1
# 2     7.587945            58.571657          0
# 3     6.387926            88.827701          1
# 4     2.404168            81.083870          0
# 5     2.403951            49.757016          0
# 6     1.522753            94.655631          0
# 7     8.795585            89.352235          1
# 8     6.410035            96.987995          1
# 9     7.372653            83.543171          1

# %%
import numpy as np
array = np.array([[0,1,2],[3,2,4]])
print(array)
# Out:
# [[0 1 2]
#  [3 2 4]]

# %%
# importing "array" for array operations
import array

# initializing array with array values and signed integers
arr = array.array('i', [1, 2, 3]) 

# printing original array
print ("The new created array is : ",end=" ")
for i in range (0, 3):
	print (arr[i], end=" ")
print("\r")

# using append() to insert new value at end
arr.append(4);

# printing appended array
print("The appended array is : ", end="")
for i in range (len(arr)):
	print (arr[i], end=" ")
# Out:
# The new created array is :  1 2 3
# The appended array is : 1 2 3 4

# %%
# importing "array" for array operations
import array

# initializing array with array values and signed integers
arr = array.array('i', [1, 2, 3]) 

# printing original array
print ("The new created array is : ",end=" ")
for i in range (0, 3):
	print (arr[i], end=" ")

arr.insert(2, 5)

print("\r")

# printing array after insertion
print ("The array after insertion is : ", end="")
for i in range (len(arr)):
	print (arr[i], end=" ")
# Out:
# The new created array is :  1 2 3
# The array after insertion is : 1 2 5 3

# %%
# importing "array" for array operations
import array

# initializing array with array values
arr= array.array('i',[1, 2, 3, 1, 5])

# printing original array
print ("The new created array is : ",end="")
for i in range (0,5):
	print (arr[i],end=" ")

print("\r")

# using pop() to remove element at 2nd position
print ("The popped element is : ",end="")
print (arr.pop(2));

# printing array after popping
print ("The array after popping is : ",end="")
for i in range (len(arr)):
	print (arr[i],end=" ")
# Out:
# The new created array is : 1 2 3 1 5
# The popped element is : 3
# The array after popping is : 1 2 1 5

# %%
# importing "array" for array operations
import array

# initializing array with array values
arr= array.array('i',[1, 2, 3, 1, 5])

# printing original array
print ("The new created array is : ",end="")
for i in range (0,5):
	print (arr[i],end=" ")

print("\r")

# using remove() to remove 1st occurrence of 1
arr.remove(1)

# printing array after removing
print ("The array after removing is : ",end="")
for i in range (len(arr)):
	print (arr[i],end=" ")
# Out:
# The new created array is : 1 2 3 1 5
# The array after removing is : 2 3 1 5

# %%
# importing "array" for array operations
import array

# initializing array with array values
arr= array.array('i',[1, 2, 3, 1, 2, 5])

# printing original array
print ("The new created array is : ",end="")
for i in range (0,6):
	print (arr[i],end=" ")

print("\r")

# using index() to print index of 1st occurrence of 2
print ("The index of 1st occurrence of 2 is : ",end="")
print (arr.index(2))
# Out:
# The new created array is : 1 2 3 1 2 5
# The index of 1st occurrence of 2 is : 1

# %%
# importing "array" for array operations
import array

# initializing array with array values
arr= array.array('i',[1, 2, 3, 1, 2, 5])

# printing original array
print ("The new created array is : ",end="")
for i in range (0,6):
	print (arr[i],end=" ")

print("\r")

#using reverse() to reverse the array
arr.reverse()

# printing array after reversing
print ("The array after reversing is : ",end="")
for i in range(len(arr)):
	print (arr[i],end=" ")
# Out:
# The new created array is : 1 2 3 1 2 5
# The array after reversing is : 5 2 1 3 2 1

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

x = [100000, 105000, 200000, 205000, 300000]
y = [1.1, 1.3, 1.5, 2.0, 2.2]
df_sal = pd.DataFrame({'Salary': x, 'year': y})
plt.title('Salary Distribution Plot')
sns.distplot(df_sal['Salary'])

plt.show()
# Out:
# C:\Users\Samsung\AppData\Local\Temp\ipykernel_9916\2304867004.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df_sal['Salary'])
# C:\Users\Samsung\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

x = [100000, 105000, 200000, 205000, 300000]
y = [1.1, 1.3, 1.5, 2.0, 2.2]
df_sal = pd.DataFrame({'Salary': x, 'YearsExperience': y})
plt.title('Salary Distribution Plot')
# Relationship between Salary and Experience
plt.scatter(df_sal['YearsExperience'], df_sal['Salary'], color = 'lightcoral')
plt.title('Salary vs Experience')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.box(False)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

x = [100000, 105000, 200000, 205000, 300000]
y = [1.1, 1.3, 1.5, 2.0, 2.2]
df_sal = pd.DataFrame({'Salary': x, 'YearsExperience': y})
X = df_sal.iloc[:, :1]  # independent
y = df_sal.iloc[:, 1:]  # dependent
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)   # predicted value of y_train
plt.scatter(X_train, y_train, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Salary vs Experience (Training Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from pandas.core.common import random_state
from sklearn.linear_model import LinearRegression

x = [100000, 105000, 200000, 205000, 300000]
y = [1.1, 1.3, 1.5, 2.0, 2.2]
df_sal = pd.DataFrame({'Salary': x, 'YearsExperience': y})
X = df_sal.iloc[:, :1]  # independent
y = df_sal.iloc[:, 1:]  # dependent
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)
regressor = LinearRegression()
regressor.fit(X_train, y_train)
y_pred_test = regressor.predict(X_test)     # predicted value of y_test
y_pred_train = regressor.predict(X_train)   # predicted value of y_train
plt.scatter(X_test, y_test, color = 'lightcoral')
plt.plot(X_train, y_pred_train, color = 'firebrick')
plt.title('Salary vs Experience (Test Set)')
plt.xlabel('Years of Experience')
plt.ylabel('Salary')
plt.legend(['X_train/Pred(y_test)', 'X_train/y_train'], title = 'Sal/Exp', loc='best', facecolor='white')
plt.box(False)
plt.show()
